# %%
import os
os.listdir()
# Out:
# ['.idea',
#  'app1.py',
#  'content.txt',
#  'data.json',
#  'file1.txt',
#  'file2.txt',
#  'file3.txt',
#  'fruits.txt',
#  'interactive-dictionary.py',
#  'numbers.txt',
#  'password_check.py',
#  'section2-lecture50.py',
#  'section2-lecture55.py',
#  'section2-lexture41.py',
#  'section2-lexture48.py',
#  'section3-lecture69.py',
#  'section3-lecture71.py',
#  'temperatures.txt',
#  'test.py',
#  'supermarkets.json',
#  'supermarkets-semi-colons.txt',
#  'supermarkets-commas.txt',
#  'supermarkets.xlsx',
#  'supermarkets.csv',
#  'pandas_load_data_example.ipynb',
#  '.ipynb_checkpoints',
#  'pandas_slicing_data_from_df.ipynb',
#  'pandas_deleting_data_from_df.ipynb',
#  'pandas_updating_adding_colums_row.ipynb']

# %%
import pandas

# %%
# read directly from URL
df6 = pandas.read_csv('http://pythonhow.com/supermarkets.csv')
df6.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
# adding a column to df

# Add a new column named Continent and populate it with North America times the number of rows (df7.shape[0])
df6['Continent'] = df6.shape[0]*['North America'] 
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
# updating information
df6['Continent'] = df6['Country'] + ', ' + 'North America' # Concat information into Continent column
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees           Continent
# 0          8  USA, North America
# 1         15  USA, North America
# 2         25  USA, North America
# 3         10  USA, North America
# 4         12  USA, North America
# 5         20  USA, North America

# %%
# transposing a df
df6.T
# Out:
#                             0                   1                   2  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
#                             3                   4                   5
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
# adding a new row
df6_t = df6.T # transpose df and assign to new variable df6_t

# adding new row as column
df6_t['My new adress'] = [7, 'My Adress', 'My City', 'My State', 'My Country', 'My Name', 50, 'My Continent']
df6_t
# Out:
#                             0                   1                   2  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
#                             3                   4                   5  \
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df6 = df6_t.T
df6
# Out:
#               ID          Address           City             State  \
# 0              1     3666 21st St  San Francisco          CA 94114
# 1              2   735 Dolores St  San Francisco          CA 94119
# 2              3      332 Hill St  San Francisco  California 94114
# 3              4     3995 23rd St  San Francisco          CA 94114
# 4              5  1056 Sanchez St  San Francisco        California
# 5              6  551 Alvarado St  San Francisco          CA 94114
# My new adress  7        My Adress        My City          My State
#
#                   Country         Name Employees           Continent
# 0                     USA      Madeira         8  USA, North America
# 1                     USA  Bready Shop        15  USA, North America
# 2                     USA  Super River        25  USA, North America
# 3                     USA   Ben's Shop        10  USA, North America
# 4                     USA      Sanchez        12  USA, North America
# ...
